# %%
# This Notebook is a cheatsheet for various Python tools lik
# 
# - Matplotlib / Seaborn
# - 
# - Pandas / numpy
#
#

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from datetime import datetime

# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # simple plots

# %%
# BAR plot of PCA variance

plt.bar(range(15),pca.explained_variance_ratio_);
plt.title('Principal Components Sorted by Variance Explain');
plt.ylabel('% of Total Variance Explained');
plt.xlabel('PC factor number');

# %%
# SCATTER plot of return of correlated assets

plt.scatter(
    df.loc['AAPL.O'].implied_mkt_return,
    df.loc['NFLX.O'].implied_mkt_return,
    alpha=0.6
);
plt.xlabel('Implied Market Return from AAPL');
plt.ylabel('Implied Market Return from NFLX');

# %%
# single LINE-PLOT 

fig,axes = plt.subplots(1,1,figsize=(15,10))
axes.set_title("Time Distro")
axes.set_ylabel("# of records")
axes.set_xlabel("date")
axes.plot(market_train_full_df.time.dt.date.value_counts().sort_index().index,\
          market_train_full_df.time.dt.date.value_counts().sort_index().values)

# %%
# VIOLIN-PLOT

fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(9, 9))
axes.set_title("Daily assetCodes Violin")
axes.set_ylabel("Repetition")
axes.violinplot(list(market_train_full_df.assetCode.value_counts().values),showmeans=False,showmedians=True)

# %%
# PIE-PLOT

univers_df_dict = dict(collections.Counter(list(market_train_full_df.universe)))
percent_univers_df_dict = {k: v / total for total in (sum(univers_df_dict.values()),) for k, v in univers_df_dict.items()}
explode=(0,0.1)
labels ='notUniverse','isUniverse'
fig, ax = plt.subplots(1,1, figsize=(8,8))
ax.set_title("Univere Status")
ax.pie(list(percent_univers_df_dict.values()), explode=explode, labels=labels, autopct='%1.1f%%',shadow=True, startangle=90)

market_train_full_df.universe.value_counts()

# %% [markdown]
# *** Word-Cloud ***

# %%
from wordcloud import WordCloud

# Create the wordcloud object
wordcloud = WordCloud(width=1024, height=1024, margin=0).generate(" ".join(market_train_full_df.assetName))
 
# Display the generated image:
fig,ax = plt.subplots(1,1,figsize=(20,10))
ax.imshow(wordcloud, interpolation='bilinear')
ax.axis("off")
ax.margins(x=0, y=0)
plt.show()

# %% [markdown]
# *** Plot with multiple subplots ***

# %%
# seaborn regression and distribution plots with multi subplots

fig,axes = plt.subplots(2,2,figsize=(15,10))

sns.distplot(df_train["cov"],kde=False, ax=axes[0][0])
axes[0][0].set_title("Salt coverage")
#plt.xlabel("coverage")
#plt.ylabel("# of images")#

sns.distplot(df_train["depth"], label="train", ax=axes[0][1])
sns.distplot(df_test["depth"], label="test",ax=axes[0][1])
axes[0][1].set_title("Depth Distribution ")
axes[0][1].legend()

sns.distplot(df_train["colordepth"],kde=False, ax=axes[1][0])
axes[1][0].set_title("Colordepth Distribution")

#plt.legend(axes[0][1])

# %%
# Plotting images within multiple subplots (loop through images in pandas series)


nrows = max_images_y
ncols = max_images_x 

fig,axes= plt.subplots(nrows=nrows, ncols=ncols, figsize=(10,10))

for i, idx in enumerate(pd_series.index): 
    ax = axes[int(i/nrows),i%ncols]
    ax.imshow(pd_series[idx], cmap="Greys")

    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.set_title(idx)

plt.suptitle(title)

# %% [markdown]
# # Pandas Plots

# %% [markdown]
# Sources:
# https://www.kaggle.com/residentmario/univariate-plotting-with-pandas

# %% [markdown]
# *** PLOT STYLE ***

# %%
# PANDAS ONLY
reviews['points'].value_counts().sort_index().plot.bar(
    figsize=(12, 6),
    color='mediumvioletred',
    fontsize=16,
    title='Rankings Given by Wine Magazine',
)

# WITH MATPLOTLIB
import matplotlib.pyplot as plt
import seaborn as sns

ax = reviews['points'].value_counts().sort_index().plot.bar(
    figsize=(12, 6),
    color='mediumvioletred',
    fontsize=16
)
ax.set_title("Rankings Given by Wine Magazine", fontsize=20)

sns.despine(bottom=True, left=True) # remove frame

# %% [markdown]
# *** Univariate Pandas Plots***
#
# - All the inputs of the univariate plots are pandasSeries

# %%
# BAR PLOT
#absteigend
reviews['province'].value_counts().head(10).plot.bar()
# index basierend
reviews['points'].value_counts().sort_index().plot.bar()


# LINE PLOT
reviews['points'].value_counts().sort_index().plot.line()

# AREA-PLOT
reviews['points'].value_counts().sort_index().plot.AREA()

# HIST-PLOT
reviews[reviews['price'] < 200]['price'].plot.hist()

# %% [markdown]
# ***Bivariate Pandas Plots***
# - All the inputs of the univariate plots are pandas DataFrames

# %%
# MULTI-LINE PLOTS 
wine_counts.plot.line() # plots each column (y) over x-axis (index)

# SCATTER-PLOT
reviews[reviews['price'] < 100].sample(100).plot.scatter(x='price', y='points')

# HEXA-PLOT
reviews[reviews['price'] < 100].plot.hexbin(x='price', y='points', gridsize=15)

# STACKED BAR-PLOT
wine_counts.plot.bar(stacked=True) # stackes the columns ontop -> Bar for each index

# STACKED AREA PLOT
wine_counts.plot.area()

# %% [markdown]
# *** advanced pandas plots ***
# - based on groupby

# %%
# STACKED BAR-PLOT
# stackes the mean of "attack" and "defense" for groups "legendary*generation"
pokemon_stats_legendary = pokemon.groupby(['Legendary', 'Generation']).mean()[['Attack', 'Defense']]


# MULTI-LINE PLOT
# plots the mean of multiple features based on groups of GENERATION
pokemon_stats_by_generation = pokemon.groupby('Generation').mean()\
                            [['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']]

# %%
# BOX-PLOTS of multiple columns/features

fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(15, 8))
axes.set_title("Box Plot")
axes.set_ylabel("Returns")
market_train_full_df.boxplot(column=['returnsClosePrevRaw1', 'returnsOpenPrevRaw1', "returnsClosePrevRaw10","returnsOpenPrevRaw10","returnsOpenNextMktres10"])

# %% [markdown]
# *** Pandas Subplots ***

# %%
fig, axarr = plt.subplots(2, 2, figsize=(12, 8))

reviews['points'].value_counts().sort_index().plot.bar(
    ax=axarr[0][0], fontsize=12, color='mediumvioletred'
)
axarr[0][0].set_title("Wine Scores", fontsize=18)

reviews['variety'].value_counts().head(20).plot.bar(
    ax=axarr[1][0], fontsize=12, color='mediumvioletred'
)
axarr[1][0].set_title("Wine Varieties", fontsize=18)

reviews['province'].value_counts().head(20).plot.bar(
    ax=axarr[1][1], fontsize=12, color='mediumvioletred'
)
axarr[1][1].set_title("Wine Origins", fontsize=18)

reviews['price'].value_counts().plot.hist(
    ax=axarr[0][1], fontsize=12, color='mediumvioletred'
)
axarr[0][1].set_title("Wine Prices", fontsize=18)

plt.subplots_adjust(hspace=.3)

import seaborn as sns
sns.despine()

# %% [markdown]
# # Seaborn

# %%
# BAR-PLOT
sns.countplot(reviews['points'])

# HIST / DENSITY PLOT
sns.distplot(reviews['points'], bins=10, kde=False)


# JOINT-PLOT
# v1
sns.jointplot(x='price', y='points', data=reviews[reviews['price'] < 100])
# v2
g = sns.jointplot(x="cov", y="depth", data=df, kind="reg",
                 xlim=(-0.05, 1.05), ylim=(0, 1000), marginal_kws=dict(bins=15, rug=True))
g.fig.suptitle("coverage vs depth")

#v3 HEXA-PLOT
sns.jointplot(x='price', y='points', data=reviews[reviews['price'] < 100], kind='hex', 
              gridsize=20)


# BOX-PLOTS
sns.boxplot(
    x='variety',
    y='points',
    data=df
)

# VIOLIN-PLOT
sns.violinplot(
    x='variety',
    y='points',
    data=reviews[reviews.variety.isin(reviews.variety.value_counts()[:5].index)]
)

# %%
# KERNEL DENSITY ESTIMATION PLOT
# smoothes out outliers to give a smoother line / noiseresitant compared to lineplot
sns.kdeplot(reviews.query('price < 200').price)

# 2d KDE-PLOT
# gibt höhenlinien
sns.kdeplot(reviews[reviews['price'] < 200].loc[:, ['price', 'points']].dropna().sample(5000))

# %%
# HEATMAP-PLOT
sns.heatmap(
    pokemon.loc[:, ['HP', 'Attack', 'Sp. Atk', 'Defense', 'Sp. Def', 'Speed']].corr(),
    annot=True
)

# %% [markdown]
# *** SEABORN FACETTE PLOTS ***
#
# Faceting is the act of breaking data variables up across multiple subplots, and combining those subplots into a single figure. So instead of one bar chart, we might have, say, four, arranged together in a grid.

# %%
# FACETTE PLOT OVER COLUMNS
# this plot creates columnwies graphs for each "Position" and plots the KDE of feature "Overall" 
# similarity to groupby
g = sns.FacetGrid(df, col="Position", col_wrap=6)
g.map(sns.kdeplot, "Overall")

# FACETTE PLOT OVER COLUMNS AND ROWS

df = footballers[footballers['Position'].isin(['ST', 'GK'])]
df = df[df['Club'].isin(['Real Madrid CF', 'FC Barcelona', 'Atlético Madrid'])]
# this plot creates columnwies graphs for each "Club" and rowise for each "position" 
# and plots the KDE of feature "Overall" 
g = sns.FacetGrid(df, row="Position", col="Club")
g.map(sns.violinplot, "Overall")

# more explicitly given each group for each graph
g = sns.FacetGrid(df, row="Position", col="Club", 
                  row_order=['GK', 'ST'],
                  col_order=['Atlético Madrid', 'FC Barcelona', 'Real Madrid CF'])
g.map(sns.violinplot, "Overall")

# %% [markdown]
# *** SEABORN PAIR PLOTS ***
#
# pairplot is a very useful and widely used seaborn method for faceting variables (as opposed to variable values). You pass it a pandas DataFrame in the right shape, and it returns you a gridded result of your variable values:

# %%
sns.pairplot(footballers[['Overall', 'Potential', 'Value']])

# %% [markdown]
# # Interactive Plots
# *** graph objects ***

# %%
import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls

# %%
# VERSION 1: BAR-PLOT - EXPLICITLY DEFINE DATA WHICH IS TO BE PLOTTET

# principle_ data (list) and layout form the cornerstones and are fed into py.iplot via dictionary
data = go.Bar(
    x = assets_over_time.loc[assets_over_time["time"]>datetime.strptime("2008-02-01", '%Y-%m-%d').date()].time, # asset1_df['time'].dt.strftime(date_format='%Y-%m-%d').values,
    y = assets_over_time.loc[assets_over_time["time"]>datetime.strptime("2008-02-01", '%Y-%m-%d').date()]["assetCode"]["count"]
)

layout = dict(title = "# of assets by trading days",
              xaxis = dict(title = 'Year'),
              yaxis = dict(title = '# of assets'),
              )
data = [data]

py.iplot(dict(data=data, layout=layout), filename='basic-line')

# %%
# VERSION 2: SCATTER-PLOT - ADD DATA VIA FOR LOOP

# principle_ data and layout form the cornerstones and are fed into py.iplot

data=[]
for ass in ["OPK.O", "OPK.N","OPK.A","IMAX.N","IMAX.O","LTR.N","L.N"]:
    data.append(go.Scatter(
        x = market_train_df[(market_train_df["assetCode"]==ass)].time,
        y = market_train_df[(market_train_df["assetCode"]==ass)].open,
        name=ass))
    
layout= dict(title="Open Price of Companies, whos assetCode Change over time", xaxis=dict(title="Year"), yaxis=dict(title="Dollari"))
    
py.iplot(dict(data=data, layout=layout), filename='basic-line')

# %%
### PANDAS + NUMPY DATA Insights

# %%
# group pandas dataframe by rounded value "a"

df.groupby(sf['a'].apply(lambda x: round(x, 1))).count()

# %%
# find correlations between two columns
# separating the correlation analysis into intervals (Bins)

df_train['bin'] = pd.cut(df_train.x,3) # creating bin of depth 
print(df_train.groupby("bin")["y"].mean())
print("\n")
for i in sorted(df_train["bin"].values.unique()):
    print(i.left, i.right)
    print(df_train.loc[(df_train["x"] >i.left) & (df_train["x"] < i.right), ["y", "x"]].corr())

# %%
## visualize training history

import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

FILENAME = "/home/niggl/MachineLearning/Kaggle/TGS_Salt/Data/19_09_URes_Augm_50ep_64bs_sgd/model_resnet50_19_9_8_64BS_50EP.h58.csv"
df_hist = pd.read_csv(FILENAME)
df_hist.keys()
# Out:
# Index(['epoch', 'acc', 'competitionMetric2', 'loss', 'lr', 'val_acc',
#        'val_competitionMetric2', 'val_loss'],
#       dtype='object')

# %%
## this is wrong usage! 

fig, axes = plt.subplots(2,1,figsize=(12,6))

axes[0] = df_hist["acc"].plot(label = "acc")
axes[0] = df_hist["val_acc"].plot(label = "val_acc")
axes[0].set_title("Accuracy")
axes[0].legend()

axes[1] = df_hist["loss"].plot(label = "acc")
axes[1] = df_hist["val_loss"].plot(label = "val_acc")
axes[1].set_title("Accuracy")
axes[1].legend()

# %%
# source: https://matplotlib.org/api/_as_gen/matplotlib.axes.Axes.plot.html

fig, axes = plt.subplots(2,2,figsize=(12,6))

axes[0][0].plot(df_hist["acc"],label = "acc")
axes[0][0].plot(df_hist["val_acc"],label = "val_acc")
axes[0][0].set_title("Accuracy")
axes[0][0].legend()

axes[1][0].plot(df_hist["loss"],color = "r", label = "acc")
axes[1][0].plot(df_hist["val_loss"],color = "g",label = "val_acc")
axes[1][0].set_title("Loss")
axes[1][0].legend()

axes[0][1].plot(df_hist["competitionMetric2"],label = "Metric Train")
axes[0][1].plot(df_hist["val_competitionMetric2"],label = "Metric Val")
axes[0][1].set_title("LB Metric")
axes[0][1].legend()

axes[1][1].semilogy(df_hist["lr"],color = "r", label = "lr")
#axes[1][1].plot(df_hist["val_loss"],color = "g",label = "val_acc")
axes[1][1].set_title("Learning Rate")
axes[1][1].legend()

# %%
FILENAME = "/home/niggl/MachineLearning/Kaggle/TGS_Salt/Data/resnet50_19_9_13_64BS_20EP_sgd/model_resnet50_19_9_13_64BS_20EP.h513.csv"
df_hist = pd.read_csv(FILENAME)
df_hist.keys()
# Out:
# Index(['epoch', 'acc', 'competitionMetric2', 'loss', 'lr', 'val_acc',
#        'val_competitionMetric2', 'val_loss'],
#       dtype='object')

# %%
# source: https://matplotlib.org/api/_as_gen/matplotlib.axes.Axes.plot.html

fig, axes = plt.subplots(2,2,figsize=(12,6))

axes[0][0].plot(df_hist["acc"],label = "acc")
axes[0][0].plot(df_hist["val_acc"],label = "val_acc")
axes[0][0].set_title("Accuracy")
axes[0][0].legend()

axes[1][0].plot(df_hist["loss"],color = "r", label = "acc")
axes[1][0].plot(df_hist["val_loss"],color = "g",label = "val_acc")
axes[1][0].set_title("Loss")
axes[1][0].legend()

axes[0][1].plot(df_hist["competitionMetric2"],label = "Metric Train")
axes[0][1].plot(df_hist["val_competitionMetric2"],label = "Metric Val")
axes[0][1].set_title("LB Metric")
axes[0][1].legend()

axes[1][1].semilogy(df_hist["lr"],color = "r", label = "lr")
#axes[1][1].plot(df_hist["val_loss"],color = "g",label = "val_acc")
axes[1][1].set_title("Learning Rate")
axes[1][1].legend()

# %%
FILENAME = "/home/niggl/MachineLearning/Kaggle/TGS_Salt/Data/resnet50_19_9_14_64BS_50EP/model_resnet50_19_9_14_64BS_50EP.csv"
df_hist = pd.read_csv(FILENAME)
df_hist.keys()
# Out:
# Index(['epoch', 'acc', 'competitionMetric2', 'loss', 'lr', 'val_acc',
#        'val_competitionMetric2', 'val_loss'],
#       dtype='object')

# %%
# source: https://matplotlib.org/api/_as_gen/matplotlib.axes.Axes.plot.html

fig, axes = plt.subplots(2,2,figsize=(12,6))

axes[0][0].plot(df_hist["acc"],label = "acc")
axes[0][0].plot(df_hist["val_acc"],label = "val_acc")
axes[0][0].set_title("Accuracy")
axes[0][0].legend()

axes[1][0].plot(df_hist["loss"],color = "r", label = "acc")
axes[1][0].plot(df_hist["val_loss"],color = "g",label = "val_acc")
axes[1][0].set_title("Loss")
axes[1][0].legend()

axes[0][1].plot(df_hist["competitionMetric2"],label = "Metric Train")
axes[0][1].plot(df_hist["val_competitionMetric2"],label = "Metric Val")
axes[0][1].set_title("LB Metric")
axes[0][1].legend()

axes[1][1].semilogy(df_hist["lr"],color = "r", label = "lr")
#axes[1][1].plot(df_hist["val_loss"],color = "g",label = "val_acc")
axes[1][1].set_title("Learning Rate")
axes[1][1].legend()

# %%
FILENAME = "/home/niggl/MachineLearning/Kaggle/TGS_Salt/Data/resnet50_20_9_9_64BS_50EP/model_resnet50_20_9_9_64BS_50EP.csv"
df_hist = pd.read_csv(FILENAME)
df_hist.keys()
# Out:
# Index(['epoch', 'acc', 'competitionMetric2', 'loss', 'lr', 'val_acc',
#        'val_competitionMetric2', 'val_loss'],
#       dtype='object')

# %%
# source: https://matplotlib.org/api/_as_gen/matplotlib.axes.Axes.plot.html

fig, axes = plt.subplots(2,2,figsize=(12,6))

axes[0][0].plot(df_hist["acc"],label = "acc")
axes[0][0].plot(df_hist["val_acc"],label = "val_acc")
axes[0][0].set_title("Accuracy")
axes[0][0].legend()

axes[1][0].plot(df_hist["loss"],color = "r", label = "acc")
axes[1][0].plot(df_hist["val_loss"],color = "g",label = "val_acc")
axes[1][0].set_title("Loss")
axes[1][0].legend()

axes[0][1].plot(df_hist["competitionMetric2"],label = "Metric Train")
axes[0][1].plot(df_hist["val_competitionMetric2"],label = "Metric Val")
axes[0][1].set_title("LB Metric")
axes[0][1].legend()

axes[1][1].semilogy(df_hist["lr"],color = "r", label = "lr")
#axes[1][1].plot(df_hist["val_loss"],color = "g",label = "val_acc")
axes[1][1].set_title("Learning Rate")
axes[1][1].legend()

# %%
## PLOT CONFUSION MATRIX IN A PRESENTABLE MANNER
import itertools

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# Compute confusion matrix
#cnf_matrix = confusion_matrix(y_test, y_pred)
cnf_matrix = confusion_matrix(df_pred["model_av"], df_pred["true"] )
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=["non-empty", "empty"],
                      title='Confusion matrix, without normalization')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=["non-empty", "empty"], normalize=True,
                      title='Normalized confusion matrix')

plt.show()
